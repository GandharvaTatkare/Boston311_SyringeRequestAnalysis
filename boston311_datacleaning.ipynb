# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
import re

# %%
# Define API details
BASE_URL = "https://data.boston.gov/api/3/action/datastore_search"
RESOURCE_IDS = [
    "9d7c2214-4709-478a-a2e8-fb2020a5bb94"
]

def fetch_data(resource_id):
    """Fetch data from the API given a resource ID."""
    offset = 0
    limit = 100000  # Adjust based on API limits
    all_records = []

    while True:
        params = {"resource_id": resource_id, "limit": limit, "offset": offset}
        response = requests.get(BASE_URL, params=params)

        if response.status_code == 200:
            data = response.json()
            records = data.get("result", {}).get("records", [])
            if not records:
                break
            all_records.extend(records)
            offset += limit
        else:
            print(f"Failed to fetch data for resource {resource_id}: {response.status_code}")
            break

    return pd.DataFrame(all_records) if all_records else pd.DataFrame()

def main():
    """Fetch and combine data from all resource IDs."""
    all_data = []

    for resource_id in RESOURCE_IDS:
        print(f"Fetching data for resource ID: {resource_id}")
        df = fetch_data(resource_id)
        if not df.empty:
            all_data.append(df)

    if all_data:
        combined_df = pd.concat(all_data, ignore_index=True)
        combined_df.to_csv("boston_311_2025T1.csv", index=False)
        print("Data fetching complete. Saved as 'boston_311_combined.csv'.")
    else:
        print("No data was fetched.")

if __name__ == "__main__": #__name__ corrected here
    main()
# Out:
# Fetching data for resource ID: 9d7c2214-4709-478a-a2e8-fb2020a5bb94
# Data fetching complete. Saved as 'boston_311_combined.csv'.

# %%
df = pd.read_csv("boston_311_2025T1.csv")
df.head()
# Out:
#    _id  case_enquiry_id              open_dt        sla_target_dt  \
# 0    1     101005897291  2025-01-31 11:02:14                  NaN
# 1    2     101005897292  2025-01-31 11:02:32  2025-02-03 11:02:35
# 2    3     101005897280  2025-01-31 10:46:00  2025-02-01 10:46:28
# 3    4     101005922144  2025-02-21 16:28:44  2025-02-23 16:28:46
# 4    5     101005922146  2025-02-21 16:34:00  2025-03-10 04:30:00
#
#              closed_dt  on_time case_status  \
# 0  2025-01-31 11:39:03   ONTIME      Closed
# 1  2025-01-31 14:01:52   ONTIME      Closed
# 2  2025-02-03 03:10:00  OVERDUE      Closed
# 3  2025-02-22 05:53:26   ONTIME      Closed
# 4                  NaN  OVERDUE        Open
#
#                                       closure_reason  \
# 0  Case Closed. Closed date : Fri Jan 31 16:39:03...
# 1  Case Closed. Closed date : Fri Jan 31 19:01:52...
# 2  Case Closed. Closed date : 2025-02-03 08:10:00...
# 3  Case Closed. Closed date : Sat Feb 22 10:53:26...
# 4
#
#                     case_title                            subject  ...  \
# 0                Needle Pickup            Mayor's 24 Hour Hotline  ...
# 1          Pick up Dead Animal            Public Works Department  ...
# 2  Unsafe/Dangerous Conditions              Inspectional Services  ...
# 3          Unshoveled Sidewalk            Public Works Department  ...
# 4                  Sign Repair  Transportation - Traffic Division  ...
#
#                                    neighborhood  \
# 0                                    Dorchester
# 1                                     South End
# 2  Fenway / Kenmore / Audubon Circle / Longwood
# 3                                     Hyde Park
# 4                                    Dorchester
#
#   neighborhood_services_district     ward precinct  \
# 0                              7       13     1303
# 1                              6   Ward 4     0403
# 2                             14   Ward 5     0502
# 3                             10  Ward 18     1806
# 4                              7       16     1611
#
#                     location_street_name location_zipcode   latitude  \
# 0                    151 Mount Vernon St           2125.0  42.320813
# 1                         85 Pembroke St           2118.0  42.342070
# 2                      19 Queensberry St           2215.0  42.343320
# 3                            54 Tampa St           2126.0  42.272330
# 4  INTERSECTION Milton St &amp; Adams St              NaN  42.280036
#
#    longitude                                          geom_4326  \
# 0 -71.051774  0101000020E6100000B1223E4350C351C06A1DE2641029...
# 1 -71.076121  0101000020E6100000454C9D28DFC451C073E552EFC82B...
# 2 -71.095884  0101000020E610000054C8D1F422C651C07B5D4CE5F12B...
# 3 -71.109231  0101000020E6100000BAC2FCA2FDC651C01E6B3FB2DB22...
# 4 -71.058942  0101000020E6100000A68279B4C5C351C0B4F4CF34D823...
#
#                  source
# 0  Citizens Connect App
# 1  Citizens Connect App
# 2    Employee Generated
# 3    Employee Generated
# 4    Employee Generated
#
# [5 rows x 31 columns]

# %%
df.shape
# Out:
# (32000, 31)

# %%
import re
import nltk
from nltk.corpus import stopwords
nltk.download()
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> d
#
# Download which package (l=list; x=cancel)?
#   Identifier> l
# Packages:
#   [ ] abc................. Australian Broadcasting Commission 2006
#   [ ] alpino.............. Alpino Dutch Treebank
#   [ ] averaged_perceptron_tagger Averaged Perceptron Tagger
#   [ ] averaged_perceptron_tagger_eng Averaged Perceptron Tagger (JSON)
#   [ ] averaged_perceptron_tagger_ru Averaged Perceptron Tagger (Russian)
#   [ ] averaged_perceptron_tagger_rus Averaged Perceptron Tagger (Russian)
#   [ ] basque_grammars..... Grammars for Basque
#   [ ] bcp47............... BCP-47 Language Tags
#   [ ] biocreative_ppi..... BioCreAtIvE (Critical Assessment of Information
#                            Extraction Systems in Biology)
#   [ ] bllip_wsj_no_aux.... BLLIP Parser: WSJ Model
#   [ ] book_grammars....... Grammars from NLTK Book
#   [ ] brown............... Brown Corpus
#   [ ] brown_tei........... Brown Corpus (TEI XML Version)
#   [ ] cess_cat............ CESS-CAT Treebank
#   [ ] cess_esp............ CESS-ESP Treebank
#   [ ] chat80.............. Chat-80 Data Files
#   [ ] city_database....... City Database
#   [ ] cmudict............. The Carnegie Mellon Pronouncing Dictionary (0.6)
#   [ ] comparative_sentences Comparative Sentence Dataset
# Hit Enter to continue:
#   [ ] comtrans............ ComTrans Corpus Sample
#   [ ] conll2000........... CONLL 2000 Chunking Corpus
#   [ ] conll2002........... CONLL 2002 Named Entity Recognition Corpus
#   [ ] conll2007........... Dependency Treebanks from CoNLL 2007 (Catalan
#                            and Basque Subset)
#   [ ] crubadan............ Crubadan Corpus
#   [ ] dependency_treebank. Dependency Parsed Treebank
#   [ ] dolch............... Dolch Word List
#   [ ] english_wordnet..... Open English Wordnet
#   [ ] europarl_raw........ Sample European Parliament Proceedings Parallel
#                            Corpus
#   [ ] extended_omw........ Extended Open Multilingual WordNet
#   [ ] floresta............ Portuguese Treebank
#   [ ] framenet_v15........ FrameNet 1.5
#   [ ] framenet_v17........ FrameNet 1.7
#   [ ] gazetteers.......... Gazeteer Lists
#   [ ] genesis............. Genesis Corpus
#   [ ] gutenberg........... Project Gutenberg Selections
#   [ ] ieer................ NIST IE-ER DATA SAMPLE
#   [ ] inaugural........... C-Span Inaugural Address Corpus
#   [ ] indian.............. Indian Language POS-Tagged Corpus
# Hit Enter to continue:
#   [ ] jeita............... JEITA Public Morphologically Tagged Corpus (in
#                            ChaSen format)
#   [ ] kimmo............... PC-KIMMO Data Files
#   [ ] knbc................ KNB Corpus (Annotated blog corpus)
#   [ ] large_grammars...... Large context-free and feature-based grammars
#                            for parser comparison
#   [ ] lin_thesaurus....... Lin's Dependency Thesaurus
#   [ ] mac_morpho.......... MAC-MORPHO: Brazilian Portuguese news text with
#                            part-of-speech tags
#   [ ] machado............. Machado de Assis -- Obra Completa
#   [ ] masc_tagged......... MASC Tagged Corpus
#   [ ] maxent_ne_chunker... ACE Named Entity Chunker (Maximum entropy)
#   [ ] maxent_ne_chunker_tab ACE Named Entity Chunker (Maximum entropy)
#   [ ] maxent_treebank_pos_tagger Treebank Part of Speech Tagger (Maximum entropy)
#   [ ] maxent_treebank_pos_tagger_tab Treebank Part of Speech Tagger (Maximum entropy)
#   [ ] moses_sample........ Moses Sample Models
#   [ ] movie_reviews....... Sentiment Polarity Dataset Version 2.0
#   [ ] mte_teip5........... MULTEXT-East 1984 annotated corpus 4.0
#   [ ] mwa_ppdb............ The monolingual word aligner (Sultan et al.
#                            2015) subset of the Paraphrase Database.
#   [ ] names............... Names Corpus, Version 1.3 (1994-03-29)
# Hit Enter to continue:
#   [ ] nombank.1.0......... NomBank Corpus 1.0
#   [ ] nonbreaking_prefixes Non-Breaking Prefixes (Moses Decoder)
#   [ ] nps_chat............ NPS Chat
#   [ ] omw-1.4............. Open Multilingual Wordnet
#   [ ] omw................. Open Multilingual Wordnet
#   [ ] opinion_lexicon..... Opinion Lexicon
#   [ ] panlex_swadesh...... PanLex Swadesh Corpora
#   [ ] paradigms........... Paradigm Corpus
#   [ ] pe08................ Cross-Framework and Cross-Domain Parser
#                            Evaluation Shared Task
#   [ ] perluniprops........ perluniprops: Index of Unicode Version 7.0.0
#                            character properties in Perl
#   [ ] pil................. The Patient Information Leaflet (PIL) Corpus
#   [ ] pl196x.............. Polish language of the XX century sixties
#   [ ] porter_test......... Porter Stemmer Test Files
#   [ ] ppattach............ Prepositional Phrase Attachment Corpus
#   [ ] problem_reports..... Problem Report Corpus
#   [ ] product_reviews_1... Product Reviews (5 Products)
#   [ ] product_reviews_2... Product Reviews (9 Products)
#   [ ] propbank............ Proposition Bank Corpus 1.0
#   [ ] pros_cons........... Pros and Cons
# Hit Enter to continue:
#   [ ] ptb................. Penn Treebank
#   [ ] punkt............... Punkt Tokenizer Models
#   [ ] punkt_tab........... Punkt Tokenizer Models
#   [ ] qc.................. Experimental Data for Question Classification
#   [ ] reuters............. The Reuters-21578 benchmark corpus, ApteMod
#                            version
#   [ ] rslp................ RSLP Stemmer (Removedor de Sufixos da Lingua
#                            Portuguesa)
#   [ ] rte................. PASCAL RTE Challenges 1, 2, and 3
#   [ ] sample_grammars..... Sample Grammars
#   [ ] semcor.............. SemCor 3.0
#   [ ] senseval............ SENSEVAL 2 Corpus: Sense Tagged Text
#   [ ] sentence_polarity... Sentence Polarity Dataset v1.0
#   [ ] sentiwordnet........ SentiWordNet
#   [ ] shakespeare......... Shakespeare XML Corpus Sample
#   [ ] sinica_treebank..... Sinica Treebank Corpus Sample
#   [ ] smultron............ SMULTRON Corpus Sample
#   [ ] snowball_data....... Snowball Data
#   [ ] spanish_grammars.... Grammars for Spanish
#   [ ] state_union......... C-Span State of the Union Address Corpus
#   [ ] stopwords........... Stopwords Corpus
# Hit Enter to continue:
#   [ ] subjectivity........ Subjectivity Dataset v1.0
#   [ ] swadesh............. Swadesh Wordlists
#   [ ] switchboard......... Switchboard Corpus Sample
#   [ ] tagsets............. Help on Tagsets
#   [ ] tagsets_json........ Help on Tagsets (JSON)
#   [ ] timit............... TIMIT Corpus Sample
#   [ ] toolbox............. Toolbox Sample Files
#   [ ] treebank............ Penn Treebank Sample
#   [ ] twitter_samples..... Twitter Samples
#   [ ] udhr2............... Universal Declaration of Human Rights Corpus
#                            (Unicode Version)
#   [ ] udhr................ Universal Declaration of Human Rights Corpus
#   [ ] unicode_samples..... Unicode Samples
#   [ ] universal_tagset.... Mappings to the Universal Part-of-Speech Tagset
#   [ ] universal_treebanks_v20 Universal Treebanks Version 2.0
#   [ ] vader_lexicon....... VADER Sentiment Lexicon
#   [ ] verbnet3............ VerbNet Lexicon, Version 3.3
#   [ ] verbnet............. VerbNet Lexicon, Version 2.1
#   [ ] webtext............. Web Text Corpus
#   [ ] wmt15_eval.......... Evaluation data from WMT15
#   [ ] word2vec_sample..... Word2Vec Sample
# Hit Enter to continue:
#   [ ] wordnet2021......... Open English Wordnet 2021
#   [ ] wordnet2022......... Open English Wordnet 2022
#   [ ] wordnet31........... Wordnet 3.1
#   [ ] wordnet............. WordNet
#   [ ] wordnet_ic.......... WordNet-InfoContent
#   [ ] words............... Word Lists
#   [ ] ycoe................ York-Toronto-Helsinki Parsed Corpus of Old
#                            English Prose
#
# Collections:
#   [ ] all-corpora......... All the corpora
#   [ ] all-nltk............ All packages available on nltk_data gh-pages
#                            branch
#   [ ] all................. All packages
#   [ ] book................ Everything used in the NLTK Book
#   [ ] popular............. Popular packages
#   [ ] tests............... Packages for running tests
#   [ ] third-party......... Third-party data packages
#
# ([*] marks installed packages)
#
# Download which package (l=list; x=cancel)?
#   Identifier>
#
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> q
# True

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
df_f = df[['case_enquiry_id', 'closure_reason','case_title']]

# %%
df_f.head()
# Out:
#    case_enquiry_id                                     closure_reason  \
# 0     101005897291  Case Closed. Closed date : Fri Jan 31 16:39:03...
# 1     101005897292  Case Closed. Closed date : Fri Jan 31 19:01:52...
# 2     101005897280  Case Closed. Closed date : 2025-02-03 08:10:00...
# 3     101005922144  Case Closed. Closed date : Sat Feb 22 10:53:26...
# 4     101005922146
#
#                     case_title
# 0                Needle Pickup
# 1          Pick up Dead Animal
# 2  Unsafe/Dangerous Conditions
# 3          Unshoveled Sidewalk
# 4                  Sign Repair

# %%
def remove_pun(text):
    nonpun = "".join([char for char in text if char not in string.punctuation and not char.isdigit()])
    return nonpun.strip()

df_f['cr_clean'] = df_f['closure_reason'].apply(lambda x: remove_pun(x))
df_f.head()
# Out:
# <ipython-input-9-c885e9eac6be>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_f['cr_clean'] = df_f['closure_reason'].apply(lambda x: remove_pun(x))
#    case_enquiry_id                                     closure_reason  \
# 0     101005897291  Case Closed. Closed date : Fri Jan 31 16:39:03...
# 1     101005897292  Case Closed. Closed date : Fri Jan 31 19:01:52...
# 2     101005897280  Case Closed. Closed date : 2025-02-03 08:10:00...
# 3     101005922144  Case Closed. Closed date : Sat Feb 22 10:53:26...
# 4     101005922146
#
#                     case_title  \
# 0                Needle Pickup
# 1          Pick up Dead Animal
# 2  Unsafe/Dangerous Conditions
# 3          Unshoveled Sidewalk
# 4                  Sign Repair
#
#                                             cr_clean
# 0  Case Closed Closed date  Fri Jan   EST  Resolv...
# 1   Case Closed Closed date  Fri Jan   EST  Resolved
# 2  Case Closed Closed date    Duplicate of Existi...
# 3  Case Closed Closed date  Sat Feb   EST  Noted ...
# 4

# %%
def tokenize(text):
    token = re.split('\W+', text)
    return token

df_f['cr_tokenized'] = df_f['cr_clean'].apply(lambda x: tokenize(x.lower()))
df_f.head()
# Out:
# <ipython-input-10-14cbbe1f0ba8>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_f['cr_tokenized'] = df_f['cr_clean'].apply(lambda x: tokenize(x.lower()))
#    case_enquiry_id                                     closure_reason  \
# 0     101005897291  Case Closed. Closed date : Fri Jan 31 16:39:03...
# 1     101005897292  Case Closed. Closed date : Fri Jan 31 19:01:52...
# 2     101005897280  Case Closed. Closed date : 2025-02-03 08:10:00...
# 3     101005922144  Case Closed. Closed date : Sat Feb 22 10:53:26...
# 4     101005922146
#
#                     case_title  \
# 0                Needle Pickup
# 1          Pick up Dead Animal
# 2  Unsafe/Dangerous Conditions
# 3          Unshoveled Sidewalk
# 4                  Sign Repair
#
#                                             cr_clean  \
# 0  Case Closed Closed date  Fri Jan   EST  Resolv...
# 1   Case Closed Closed date  Fri Jan   EST  Resolved
# 2  Case Closed Closed date    Duplicate of Existi...
# 3  Case Closed Closed date  Sat Feb   EST  Noted ...
# 4
#
#                                         cr_tokenized
# 0  [case, closed, closed, date, fri, jan, est, re...
# 1  [case, closed, closed, date, fri, jan, est, re...
# 2  [case, closed, closed, date, duplicate, of, ex...
# 3  [case, closed, closed, date, sat, feb, est, no...
# 4                                                 []

# %%
# Removing stop words
from nltk.corpus import stopwords
nltk.download('stopwords')
stopwords = stopwords.words('english')

def remove_sw(text_list):
    filtered = [word for word in text_list if word not in stopwords]
    return filtered

df_f['cr_filtered'] = df_f['cr_tokenized'].apply(lambda x: remove_sw(x))

df_f.head()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# <ipython-input-11-8c0092e80d60>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_f['cr_filtered'] = df_f['cr_tokenized'].apply(lambda x: remove_sw(x))
#    case_enquiry_id                                     closure_reason  \
# 0     101005897291  Case Closed. Closed date : Fri Jan 31 16:39:03...
# 1     101005897292  Case Closed. Closed date : Fri Jan 31 19:01:52...
# 2     101005897280  Case Closed. Closed date : 2025-02-03 08:10:00...
# 3     101005922144  Case Closed. Closed date : Sat Feb 22 10:53:26...
# 4     101005922146
#
#                     case_title  \
# 0                Needle Pickup
# 1          Pick up Dead Animal
# 2  Unsafe/Dangerous Conditions
# 3          Unshoveled Sidewalk
# 4                  Sign Repair
#
#                                             cr_clean  \
# 0  Case Closed Closed date  Fri Jan   EST  Resolv...
# 1   Case Closed Closed date  Fri Jan   EST  Resolved
# 2  Case Closed Closed date    Duplicate of Existi...
# 3  Case Closed Closed date  Sat Feb   EST  Noted ...
# 4
#
#                                         cr_tokenized  \
# 0  [case, closed, closed, date, fri, jan, est, re...
# 1  [case, closed, closed, date, fri, jan, est, re...
# 2  [case, closed, closed, date, duplicate, of, ex...
# 3  [case, closed, closed, date, sat, feb, est, no...
# 4                                                 []
#
#                                          cr_filtered
# 0  [case, closed, closed, date, fri, jan, est, re...
# 1  [case, closed, closed, date, fri, jan, est, re...
# 2  [case, closed, closed, date, duplicate, existi...
# 3  [case, closed, closed, date, sat, feb, est, no...
# 4                                                 []

# %%
nltk.download('wordnet')
lm = nltk.WordNetLemmatizer()

def lemmatize_words(text):
    word_lm = [lm.lemmatize(word) for word in text ]
    return word_lm

df_f['cr_lemmatized'] = df_f['cr_filtered'].apply(lambda x: lemmatize_words(x))

df_f.head()
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# <ipython-input-12-8b11b1fed2b5>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_f['cr_lemmatized'] = df_f['cr_filtered'].apply(lambda x: lemmatize_words(x))
#    case_enquiry_id                                     closure_reason  \
# 0     101005897291  Case Closed. Closed date : Fri Jan 31 16:39:03...
# 1     101005897292  Case Closed. Closed date : Fri Jan 31 19:01:52...
# 2     101005897280  Case Closed. Closed date : 2025-02-03 08:10:00...
# 3     101005922144  Case Closed. Closed date : Sat Feb 22 10:53:26...
# 4     101005922146
#
#                     case_title  \
# 0                Needle Pickup
# 1          Pick up Dead Animal
# 2  Unsafe/Dangerous Conditions
# 3          Unshoveled Sidewalk
# 4                  Sign Repair
#
#                                             cr_clean  \
# 0  Case Closed Closed date  Fri Jan   EST  Resolv...
# 1   Case Closed Closed date  Fri Jan   EST  Resolved
# 2  Case Closed Closed date    Duplicate of Existi...
# 3  Case Closed Closed date  Sat Feb   EST  Noted ...
# 4
#
#                                         cr_tokenized  \
# 0  [case, closed, closed, date, fri, jan, est, re...
# 1  [case, closed, closed, date, fri, jan, est, re...
# 2  [case, closed, closed, date, duplicate, of, ex...
# 3  [case, closed, closed, date, sat, feb, est, no...
# 4                                                 []
#
#                                          cr_filtered  \
# 0  [case, closed, closed, date, fri, jan, est, re...
# 1  [case, closed, closed, date, fri, jan, est, re...
# 2  [case, closed, closed, date, duplicate, existi...
# 3  [case, closed, closed, date, sat, feb, est, no...
# 4                                                 []
#
#                                        cr_lemmatized
# 0  [case, closed, closed, date, fri, jan, est, re...
# 1  [case, closed, closed, date, fri, jan, est, re...
# 2  [case, closed, closed, date, duplicate, existi...
# 3  [case, closed, closed, date, sat, feb, est, no...
# 4                                                 []

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Vectorization using TF-IDF
vectorizer = TfidfVectorizer()

# Join the lemmatized words back into a single string for each document
df_f['cr_lemmatized_text'] = df_f['cr_lemmatized'].apply(lambda x: ' '.join(x))

df_f['combined_text'] = df_f['cr_lemmatized_text'] + ' ' + df_f['case_title'].astype(str)

# Use the new 'cr_lemmatized_text' column for TF-IDF vectorization
tfidf_matrix = vectorizer.fit_transform(df_f['combined_text'])

# Get vector for the keyword sentence (medical-related terms)
keywords = "needle pickup drugs syringe opioid injection"
keyword_vector = vectorizer.transform([keywords])

# Compute cosine similarity between each row and the keyword vector
similarities = cosine_similarity(tfidf_matrix, keyword_vector)

# Filter based on similarity threshold (0.2 ensures relevance)
df_f['similarity'] = similarities
# Out:
# <ipython-input-13-a97e9b73c6ab>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_f['cr_lemmatized_text'] = df_f['cr_lemmatized'].apply(lambda x: ' '.join(x))
# <ipython-input-13-a97e9b73c6ab>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_f['combined_text'] = df_f['cr_lemmatized_text'] + ' ' + df_f['case_title'].astype(str)
# <ipython-input-13-a97e9b73c6ab>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_f['similarity'] = similarities

# %%
df_f['similarity'].describe()
# Out:
# count    32000.000000
# mean         0.013057
# std          0.070945
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          0.763643
# Name: similarity, dtype: float64

# %%
df_filtered = df_f[df_f['similarity'] > 0]

# Drop the similarity column after filtering
df_filtered = df_filtered.drop(columns=['similarity'])

# %%
df_final = df[df['case_enquiry_id'].isin(df_filtered['case_enquiry_id'])]
df_final.head()
# Out:
#     _id  case_enquiry_id              open_dt sla_target_dt  \
# 0     1     101005897291  2025-01-31 11:02:14           NaN
# 48   49     101005981813  2025-03-24 16:52:49           NaN
# 71   72     101005977491  2025-03-20 04:29:26           NaN
# 74   75     101005977495  2025-03-20 04:31:10           NaN
# 99  100     101005897276  2025-01-31 10:45:39           NaN
#
#               closed_dt on_time case_status  \
# 0   2025-01-31 11:39:03  ONTIME      Closed
# 48  2025-03-25 03:08:42  ONTIME      Closed
# 71  2025-03-20 04:50:16  ONTIME      Closed
# 74  2025-03-20 04:38:59  ONTIME      Closed
# 99  2025-01-31 11:28:38  ONTIME      Closed
#
#                                        closure_reason     case_title  \
# 0   Case Closed. Closed date : Fri Jan 31 16:39:03...  Needle Pickup
# 48  Case Closed. Closed date : Tue Mar 25 07:08:42...  Needle Pickup
# 71  Case Closed. Closed date : Thu Mar 20 08:50:16...  Needle Pickup
# 74  Case Closed. Closed date : Thu Mar 20 08:38:59...  Needle Pickup
# 99  Case Closed. Closed date : Fri Jan 31 16:28:38...  Needle Pickup
#
#                     subject  ... neighborhood neighborhood_services_district  \
# 0   Mayor's 24 Hour Hotline  ...   Dorchester                              7
# 48  Mayor's 24 Hour Hotline  ...      Roxbury                              6
# 71  Mayor's 24 Hour Hotline  ...   Dorchester                             13
# 74  Mayor's 24 Hour Hotline  ...    South End                              6
# 99  Mayor's 24 Hour Hotline  ...    South End                              6
#
#       ward precinct  location_street_name location_zipcode   latitude  \
# 0       13     1303   151 Mount Vernon St           2125.0  42.320813
# 48      09     0902   68 W Springfield St           2118.0  42.337132
# 71  Ward 7     0710        11 Wendover St           2125.0  42.318280
# 74  Ward 9     0902       515 Shawmut Ave           2118.0  42.337890
# 99      08     0802      850 Harrison Ave           2118.0  42.334464
#
#     longitude                                          geom_4326  \
# 0  -71.051774  0101000020E6100000B1223E4350C351C06A1DE2641029...
# 48 -71.076843  0101000020E61000006988DDFEEAC451C04C8DD127272B...
# 71 -71.066371  0101000020E61000008D41486A3FC451C0A3F93E62BD28...
# 74 -71.077591  0101000020E610000073B04B3EF7C451C065D7F5F63F2B...
# 99 -71.074118  0101000020E6100000DCE0665ABEC451C0D292ADB8CF2A...
#
#                   source
# 0   Citizens Connect App
# 48    Employee Generated
# 71  Citizens Connect App
# 74    Employee Generated
# 99  Citizens Connect App
#
# [5 rows x 31 columns]

# %%
df_final.shape
# Out:
# (1198, 31)

# %%
del df_final

# %%
# df_final.to_csv("boston311_final.csv", index=False)

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1198 entries, 0 to 31882
# Data columns (total 31 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   _id                             1198 non-null   int64
#  1   case_enquiry_id                 1198 non-null   int64
#  2   open_dt                         1198 non-null   object
#  3   sla_target_dt                   230 non-null    object
#  4   closed_dt                       1197 non-null   object
#  5   on_time                         1198 non-null   object
#  6   case_status                     1198 non-null   object
#  7   closure_reason                  1198 non-null   object
#  8   case_title                      1198 non-null   object
#  9   subject                         1198 non-null   object
#  10  reason                          1198 non-null   object
#  11  type                            1198 non-null   object
#  12  queue                           1198 non-null   object
#  13  department                      1198 non-null   object
#  14  submitted_photo                 0 non-null      float64
#  15  closed_photo                    300 non-null    object
#  16  location                        1198 non-null   object
#  17  fire_district                   1198 non-null   object
#  18  pwd_district                    1198 non-null   object
#  19  city_council_district           1198 non-null   object
#  20  police_district                 1198 non-null   object
#  21  neighborhood                    1198 non-null   object
#  22  neighborhood_services_district  1198 non-null   object
#  23  ward                            1198 non-null   object
#  24  precinct                        1198 non-null   object
#  25  location_street_name            1198 non-null   object
#  26  location_zipcode                886 non-null    float64
#  27  latitude                        1198 non-null   float64
#  28  longitude                       1198 non-null   float64
#  29  geom_4326                       1198 non-null   object
#  30  source                          1198 non-null   object
# dtypes: float64(4), int64(2), object(25)
# memory usage: 299.5+ KB

# %% [markdown]
# Data Cleaning

# %%
df_final.drop(['geom_4326','submitted_photo','closed_photo','location'],axis=1,inplace=True)
df_final['location_zipcode'] = df_final['location_zipcode'].astype(str)
df_final['ward_number'] = df_final["ward"].str.extract(r'(\d+)', expand=False).fillna(0).astype(int)
df_final["queue_name"] = df_final["queue"].str.split('_').str[1]

# Date conversion and date extraction
df_final["open_date"] = pd.to_datetime(df_final["open_dt"], format="%Y-%m-%d %H:%M:%S").dt.date
df_final["sla_target_dt"] = pd.to_datetime(df_final["sla_target_dt"], format="%Y-%m-%d %H:%M:%S").dt.date
df_final["closed_date"] = pd.to_datetime(df_final["closed_dt"], format="%Y-%m-%d %H:%M:%S").dt.date

df_final["closed_date"] = pd.to_datetime(df_final["closed_date"])
df_final["open_date"] = pd.to_datetime(df_final["open_date"])

cols_to_int = ["fire_district", "city_council_district", "neighborhood_services_district"]
for col in cols_to_int:
    df_final[col] = pd.to_numeric(df_final[col].astype(str).str.strip(), errors='coerce').astype('Int64')


df_final["location_zipcode"] = df_final["location_zipcode"].astype(str).str.replace('.0', '', regex=False).str.replace('nan', '', regex=False)
# Convert to Int64, fill NaNs with 0, convert back to string, and pad with leading zeros
df_final["location_zipcode"] = pd.to_numeric(df_final["location_zipcode"], errors='coerce').fillna(0).astype('Int64').astype(str).str.zfill(5)
# Out:
# <ipython-input-19-1abb75242ec9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final.drop(['geom_4326','submitted_photo','closed_photo','location'],axis=1,inplace=True)
# <ipython-input-19-1abb75242ec9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['location_zipcode'] = df_final['location_zipcode'].astype(str)
# <ipython-input-19-1abb75242ec9>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['ward_number'] = df_final["ward"].str.extract(r'(\d+)', expand=False).fillna(0).astype(int)
# <ipython-input-19-1abb75242ec9>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["queue_name"] = df_final["queue"].str.split('_').str[1]
# <ipython-input-19-1abb75242ec9>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["open_date"] = pd.to_datetime(df_final["open_dt"], format="%Y-%m-%d %H:%M:%S").dt.date
# <ipython-input-19-1abb75242ec9>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["sla_target_dt"] = pd.to_datetime(df_final["sla_target_dt"], format="%Y-%m-%d %H:%M:%S").dt.date
# <ipython-input-19-1abb75242ec9>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["closed_date"] = pd.to_datetime(df_final["closed_dt"], format="%Y-%m-%d %H:%M:%S").dt.date
# <ipython-input-19-1abb75242ec9>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["closed_date"] = pd.to_datetime(df_final["closed_date"])
# <ipython-input-19-1abb75242ec9>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["open_date"] = pd.to_datetime(df_final["open_date"])
# <ipython-input-19-1abb75242ec9>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final[col] = pd.to_numeric(df_final[col].astype(str).str.strip(), errors='coerce').astype('Int64')
# <ipython-input-19-1abb75242ec9>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final[col] = pd.to_numeric(df_final[col].astype(str).str.strip(), errors='coerce').astype('Int64')
# <ipython-input-19-1abb75242ec9>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final[col] = pd.to_numeric(df_final[col].astype(str).str.strip(), errors='coerce').astype('Int64')
# <ipython-input-19-1abb75242ec9>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["location_zipcode"] = df_final["location_zipcode"].astype(str).str.replace('.0', '', regex=False).str.replace('nan', '', regex=False)
# <ipython-input-19-1abb75242ec9>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["location_zipcode"] = pd.to_numeric(df_final["location_zipcode"], errors='coerce').fillna(0).astype('Int64').astype(str).str.zfill(5)

# %%
df_final.drop(['location_street_name','_id','queue','ward'],axis=1,inplace=True)
# Out:
# <ipython-input-20-e2db29c794fe>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final.drop(['location_street_name','_id','queue','ward'],axis=1,inplace=True)

# %%
df_final.head()
# Out:
#     case_enquiry_id              open_dt sla_target_dt            closed_dt  \
# 0      101005897291  2025-01-31 11:02:14           NaT  2025-01-31 11:39:03
# 48     101005981813  2025-03-24 16:52:49           NaT  2025-03-25 03:08:42
# 71     101005977491  2025-03-20 04:29:26           NaT  2025-03-20 04:50:16
# 74     101005977495  2025-03-20 04:31:10           NaT  2025-03-20 04:38:59
# 99     101005897276  2025-01-31 10:45:39           NaT  2025-01-31 11:28:38
#
#    on_time case_status                                     closure_reason  \
# 0   ONTIME      Closed  Case Closed. Closed date : Fri Jan 31 16:39:03...
# 48  ONTIME      Closed  Case Closed. Closed date : Tue Mar 25 07:08:42...
# 71  ONTIME      Closed  Case Closed. Closed date : Thu Mar 20 08:50:16...
# 74  ONTIME      Closed  Case Closed. Closed date : Thu Mar 20 08:38:59...
# 99  ONTIME      Closed  Case Closed. Closed date : Fri Jan 31 16:28:38...
#
#        case_title                  subject          reason  ...  \
# 0   Needle Pickup  Mayor's 24 Hour Hotline  Needle Program  ...
# 48  Needle Pickup  Mayor's 24 Hour Hotline  Needle Program  ...
# 71  Needle Pickup  Mayor's 24 Hour Hotline  Needle Program  ...
# 74  Needle Pickup  Mayor's 24 Hour Hotline  Needle Program  ...
# 99  Needle Pickup  Mayor's 24 Hour Hotline  Needle Program  ...
#
#    neighborhood_services_district precinct  location_zipcode   latitude  \
# 0                               7     1303             02125  42.320813
# 48                              6     0902             02118  42.337132
# 71                             13     0710             02125  42.318280
# 74                              6     0902             02118  42.337890
# 99                              6     0802             02118  42.334464
#
#     longitude                source ward_number  queue_name  open_date  \
# 0  -71.051774  Citizens Connect App          13      Needle 2025-01-31
# 48 -71.076843    Employee Generated           9      Needle 2025-03-24
# 71 -71.066371  Citizens Connect App           7      Needle 2025-03-20
# 74 -71.077591    Employee Generated           9      Needle 2025-03-20
# 99 -71.074118  Citizens Connect App           8      Needle 2025-01-31
#
#    closed_date
# 0   2025-01-31
# 48  2025-03-25
# 71  2025-03-20
# 74  2025-03-20
# 99  2025-01-31
#
# [5 rows x 27 columns]

# %%
df_hist = pd.read_csv("boston311_final.csv")
df_hist.head()
# Out:
#    case_enquiry_id              open_dt sla_target_dt            closed_dt  \
# 0     101005402776  2024-04-08 11:09:17           NaN  2024-04-08 13:30:46
# 1     101005402777  2024-04-08 11:10:05           NaN  2024-04-08 11:38:16
# 2     101005357059  2024-03-19 06:57:55           NaN  2024-03-19 07:10:23
# 3     101005356895  2024-03-19 05:40:10           NaN  2024-03-19 05:49:12
# 4     101005579920  2024-07-22 14:11:00           NaN  2024-07-22 14:37:14
#
#   on_time case_status                                     closure_reason  \
# 0  ONTIME      Closed  Case Closed. Closed date : Mon Apr 08 17:30:46...
# 1  ONTIME      Closed  Case Closed. Closed date : Mon Apr 08 15:38:16...
# 2  ONTIME      Closed  Case Closed. Closed date : Tue Mar 19 11:10:23...
# 3  ONTIME      Closed  Case Closed. Closed date : Tue Mar 19 09:49:12...
# 4  ONTIME      Closed  Case Closed. Closed date : Mon Jul 22 18:37:14...
#
#       case_title                  subject          reason  ...  \
# 0  Needle Pickup  Mayor's 24 Hour Hotline  Needle Program  ...
# 1  Needle Pickup  Mayor's 24 Hour Hotline  Needle Program  ...
# 2  Needle Pickup  Mayor's 24 Hour Hotline  Needle Program  ...
# 3  Needle Pickup  Mayor's 24 Hour Hotline  Needle Program  ...
# 4  Needle Pickup  Mayor's 24 Hour Hotline  Needle Program  ...
#
#   neighborhood_services_district precinct  location_zipcode   latitude  \
# 0                            5.0     0601              2127  42.342090
# 1                            6.0     0404                 0  42.341127
# 2                            6.0     0404                 0  42.342563
# 3                            3.0     0306              2108  42.358549
# 4                            6.0     0901                 0  42.338770
#
#    longitude                source ward_number  queue_name   open_date  \
# 0 -71.056360  Citizens Connect App           6      Needle  2024-04-08
# 1 -71.081153  Citizens Connect App           4      Needle  2024-04-08
# 2 -71.081864  Citizens Connect App           4      Needle  2024-03-19
# 3 -71.059420  Citizens Connect App           3      Needle  2024-03-19
# 4 -71.074724  Citizens Connect App           9      Needle  2024-07-22
#
#    closed_date
# 0   2024-04-08
# 1   2024-04-08
# 2   2024-03-19
# 3   2024-03-19
# 4   2024-07-22
#
# [5 rows x 27 columns]

# %%
df_hist.shape
# Out:
# (76683, 27)

# %%
# Concatenate the dataframes.
df_cleaned = pd.concat([df_hist, df_final], ignore_index=True)
# Save the combined dataframe.
df_cleaned.to_csv("boston311_final.csv", index=False)
df_cleaned.shape
# Out:
# (77881, 27)

# %%
df_cleaned.head()
# Out:
#    case_enquiry_id              open_dt sla_target_dt            closed_dt  \
# 0     101005402776  2024-04-08 11:09:17           NaN  2024-04-08 13:30:46
# 1     101005402777  2024-04-08 11:10:05           NaN  2024-04-08 11:38:16
# 2     101005357059  2024-03-19 06:57:55           NaN  2024-03-19 07:10:23
# 3     101005356895  2024-03-19 05:40:10           NaN  2024-03-19 05:49:12
# 4     101005579920  2024-07-22 14:11:00           NaN  2024-07-22 14:37:14
#
#   on_time case_status                                     closure_reason  \
# 0  ONTIME      Closed  Case Closed. Closed date : Mon Apr 08 17:30:46...
# 1  ONTIME      Closed  Case Closed. Closed date : Mon Apr 08 15:38:16...
# 2  ONTIME      Closed  Case Closed. Closed date : Tue Mar 19 11:10:23...
# 3  ONTIME      Closed  Case Closed. Closed date : Tue Mar 19 09:49:12...
# 4  ONTIME      Closed  Case Closed. Closed date : Mon Jul 22 18:37:14...
#
#       case_title                  subject          reason  ...  \
# 0  Needle Pickup  Mayor's 24 Hour Hotline  Needle Program  ...
# 1  Needle Pickup  Mayor's 24 Hour Hotline  Needle Program  ...
# 2  Needle Pickup  Mayor's 24 Hour Hotline  Needle Program  ...
# 3  Needle Pickup  Mayor's 24 Hour Hotline  Needle Program  ...
# 4  Needle Pickup  Mayor's 24 Hour Hotline  Needle Program  ...
#
#   neighborhood_services_district precinct  location_zipcode   latitude  \
# 0                            5.0     0601              2127  42.342090
# 1                            6.0     0404                 0  42.341127
# 2                            6.0     0404                 0  42.342563
# 3                            3.0     0306              2108  42.358549
# 4                            6.0     0901                 0  42.338770
#
#    longitude                source ward_number  queue_name   open_date  \
# 0 -71.056360  Citizens Connect App           6      Needle  2024-04-08
# 1 -71.081153  Citizens Connect App           4      Needle  2024-04-08
# 2 -71.081864  Citizens Connect App           4      Needle  2024-03-19
# 3 -71.059420  Citizens Connect App           3      Needle  2024-03-19
# 4 -71.074724  Citizens Connect App           9      Needle  2024-07-22
#
#   closed_date
# 0  2024-04-08
# 1  2024-04-08
# 2  2024-03-19
# 3  2024-03-19
# 4  2024-07-22
#
# [5 rows x 27 columns]

# %%
df_final.to_csv("boston311_new_upload.csv", index=False)
df_final.shape
# Out:
# (1198, 27)
